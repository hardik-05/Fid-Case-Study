# %%
# Import python packages
import streamlit as st
import pandas as pd

# We can also use Snowpark for our analyses!
from snowflake.snowpark.context import get_active_session
session = get_active_session()

# %%
SELECT * FROM V_CUSTOMER_MEAN_MODE_RISK;

# %%
# Then, we can use the python name to turn cell2 into a Pandas dataframe
df = cell2.to_pandas()

df

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots()
sample_df = df.reset_index(drop=True)
sample_df.head()
x = np.arange(1,len(sample_df['CUSTOMER_ID']))
# ax.scatter(x,df['MEAN_RISK'],color='blue',label='Mean Risk',s=100)
# ax.scatter(x,df['MODE_RISK'],color='red',label='Mode Risk',s=100)
for i in x:
    ax.plot([i],sample_df['MEAN_RISK'][i],'o',color='red')
    ax.plot([i],sample_df['MODE_RISK'][i],'o',color='green')
    # ax.plot([i,i],[sample_df['MEAN_RISK'][i],sample_df['MODE_RISK'][i]],color='gray',linestyle='--')
# ax.set_xticks(x)
# ax.set_xticklabels(df['CUSTOMER_ID'],rotation=45)
ax.set(xlabel='Customers', ylabel='Risk Profile',
       title='Mean vs Mode Risk for Customers')
ax.legend()
plt.show()
