# %%
# Import python packages
import streamlit as st
import pandas as pd

# We can also use Snowpark for our analyses!
from snowflake.snowpark.context import get_active_session
session = get_active_session()

# %%
import pandas as pd
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
select count(customer_id), s.segment_id, risk_profile_id, engagement_type_id from customer_segment cs join segments s on cs.segment_id=s.segment_id group by s.segment_id,s.risk_profile_id,s.engagement_type_id;

# %%
df_engagement_risk=cell3.to_pandas()
df_engagement_risk

# %%
select coalesce(gender,'Others') as gender, get_age_range(age) as age_range, get_segment(gender,get_age_range(age)) as segment_id, count(customer_id)
from v_eligible_customers group by segment_id,gender,age_range having gender!='Others';

# %%
variance=df_engagement_risk.var()
print(variance)

# %%
df_age_gender=cell5.to_pandas()
df_age_gender['GENDER']=df_age_gender['GENDER'].map({'Male':1,'Female':2})
df_age_gender['AGE_RANGE']=df_age_gender['AGE_RANGE'].map({'31-40':1,'41-50':2,'51-60':3,'61-70':4,'71-80':5})
df_age_gender

# %%
age_gender_var=df_age_gender.var()
print(age_gender_var)

# %%
from scipy.stats import f_oneway
f_stat,p_value=f_oneway(variance,age_gender_var['COUNT(CUSTOMER_ID)'])
print(f_stat)
print("P Value: ",p_value)
